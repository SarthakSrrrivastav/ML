# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('classic')

x=range(0,11)
y=range(0,11)
plt.plot(x,y,marker = '3')  # You can use the keyword argument marker to emphasize each point with a specified marker:


plt.show()

# %%
s=np.random.seed(5)
print("The random numbers are:")
print(s)
# Out:
# The random numbers are:
# None

# %%
# Data labels, sizes, and colors are defined:
labels = 'Broccoli', 'Chocolate Cake', 'Blueberries', 'Raspberries'
sizes = [30, 330, 245, 210]
colors = ['green', 'brown', 'blue', 'red']

# Data is plotted:
plt.pie(sizes, labels=labels, colors=colors)

plt.show()

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=True)

plt.show()
# Out:
# C:\Users\Sarth\AppData\Local\Temp\ipykernel_8388\3449033150.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=True)
